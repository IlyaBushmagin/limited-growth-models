# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
f = pd.read_csv('us_oil.csv')
f
# Out:
#      year  volume
# 0    1860       1
# 1    1861       6
# 2    1862       8
# 3    1863       7
# 4    1864       6
# ..    ...     ...
# 156  2016    8844
# 157  2017    9357
# 158  2018   10941
# 159  2019   12289
# 160  2020   11283
#
# [161 rows x 2 columns]

# %%
plt.figure(figsize=(8, 8))
plt.plot(f['volume'])
plt.show()

# %%
F = []
F.append(f['volume'][0])
for i in range(len(f) - 1):
	F.append(F[i] + f['volume'][i + 1])

# %%
plt.figure(figsize=(8, 8))
plt.plot(F)
plt.show()

# %%
x = np.array(F[71:151])
y = f['volume'][71:151] / F[71:151]
z = np.polyfit(x, y, 1)
p = np.poly1d(z)

# %%
plt.figure(figsize=(8, 8))
plt.plot(x, p(x))
plt.plot(x, y, 'rx')
plt.show()

# %%
x_inf = -z[1] / z[0] / 2
x_inf
# Out:
# 305337.28953210695
